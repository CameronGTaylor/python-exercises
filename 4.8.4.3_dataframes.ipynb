# %%
from pydataset import data

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
df['passing_english'] = df.english >= 70
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
df.sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
df.sort_values(by=['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
df.sort_values(by=['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
df['overall_grade'] = (df.math + df.english + df.reading) / 3
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 11     Alan    92       62       72            False      75.333333

# %%
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displ           234 non-null float64
# year            234 non-null int64
# cyl             234 non-null int64
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# fl              234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.rename(columns={'cty': 'city', 'hwy': 'highway'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
(mpg.cty > mpg.hwy).any()
# Out:
# False

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.cty
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %%
max_dif = mpg.mileage_difference.max()
mpg[mpg.mileage_difference == max_dif]
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  cty  hwy fl  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f   24   36  c
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f   29   41  d
#
#           class  mileage_difference
# 107  subcompact                  12
# 223  subcompact                  12

# %%
mpg[mpg.hwy == mpg.hwy.min()]
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
#
#      hwy fl   class  mileage_difference
# 55    12  e  pickup                   3
# 60    12  e     suv                   3
# 66    12  e  pickup                   3
# 70    12  e  pickup                   3
# 127   12  e     suv                   3

# %%
mpg[mpg.hwy == mpg.hwy.max()]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
#
#           class  mileage_difference
# 213     compact                  11
# 222  subcompact                   9

# %%
mpg['average_mileage'] = (mpg.cty + mpg.hwy) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# ...

# %%
mpg.sort_values(by='average_mileage', ascending=False)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f   35
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f   33
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f   29
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f   28
# 196       toyota              corolla    1.8  1999    4  manual(m5)   f   26
# ..           ...                  ...    ...   ...  ...         ...  ..  ...
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
#
# ...

# %%
dodges = mpg[mpg.manufacturer == 'dodge']
max_mile = dodges.average_mileage.max()
min_mile = dodges.average_mileage.min()
dodges[(dodges.average_mileage == max_mile)]
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  cty  hwy fl  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f   18   24  r
#
#       class  mileage_difference  average_mileage
# 38  minivan                   6             21.0

# %%
dodges[(dodges.average_mileage == min_mile)]
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  cty  \
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
#
#     hwy fl   class  mileage_difference  average_mileage
# 55   12  e  pickup                   3             10.5
# 60   12  e     suv                   3             10.5
# 66   12  e  pickup                   3             10.5
# 70   12  e  pickup                   3             10.5

# %%
mammals = data('Mammals')

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
# weight      107 non-null float64
# speed       107 non-null float64
# hoppers     107 non-null bool
# specials    107 non-null bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
mammals.weight[mammals.speed == mammals.speed.max()]
# Out:
# 53    55.0
# Name: weight, dtype: float64

# %%
print(f'The overall percentage of specials is\
 {(mammals.specials.sum() / len(mammals)) * 100:.2f}%')
# Out:
# The overall percentage of specials is 9.35%

# %%
med_speed = mammals.speed.median()
fast_mammals_count = (mammals[mammals.hoppers].speed >= med_speed).sum()
print(f'The percentage of hoppers above the median speed is\
 {(fast_mammals_count / len(mammals)) * 100:.2f}%')
# Out:
# The percentage of hoppers above the median speed is 6.54%
